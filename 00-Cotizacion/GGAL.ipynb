# %%
pip install yfinance

# %%
import pandas as pd 
import yfinance as yf

# %%
# Crear el objeto del ticker
ticker = yf.Ticker("GGAL.BA")

# Obtener datos históricos
GGAL = ticker.history(start="2000-07-26", end="2025-05-16")

# Mostrar las columnas disponibles
print(GGAL.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
GGAL.head(10)
# Out:
#                                Open      High       Low     Close   Volume  \
# Date
# 2000-07-26 00:00:00-03:00  1.514586  1.532096  1.488322  1.514586   422242
# 2000-07-27 00:00:00-03:00  1.532096  1.540851  1.514586  1.532096   344044
# 2000-07-28 00:00:00-03:00  1.505832  1.523341  1.497077  1.505832   561980
# 2000-07-31 00:00:00-03:00  1.532096  1.540851  1.479567  1.532096   381111
# 2000-08-01 00:00:00-03:00  1.540851  1.628400  1.479567  1.540851  1968000
# 2000-08-02 00:00:00-03:00  1.558361  1.567115  1.540851  1.558361   857294
# 2000-08-03 00:00:00-03:00  1.505832  1.558361  1.505832  1.505832   698377
# 2000-08-04 00:00:00-03:00  1.505832  1.532096  1.497077  1.505832   532284
# 2000-08-07 00:00:00-03:00  1.523341  1.523341  1.488322  1.523341   373483
# 2000-08-08 00:00:00-03:00  1.532096  1.532096  1.505832  1.532096   760704
#
#                            Dividends  Stock Splits
# Date
# 2000-07-26 00:00:00-03:00        0.0           0.0
# ...

# %%
GGAL.to_csv("GGAL.csv", index=True)

# %%
# Leer el Archivo CSV y cargarlo al Data Frame
# GGAL = pd.read_csv("GGAL.csv", index_col=0, parse_dates=True)
